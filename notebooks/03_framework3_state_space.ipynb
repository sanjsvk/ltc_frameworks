# %% [markdown]
# # 03 — Framework 3: State-Space / Latent Brand-Stock
#
# Fit Kalman DLM, MCMC Latent Stock, and BSTS. Focus on S2 (spend pause).

# %%
from ltc.models.framework3 import KalmanDLM, MCMCLatentStock, BayesianStructuralTSfrom ltc.data import load_scenario, split_observed_truthfrom ltc.evaluation import score_modelfrom ltc.visualization import plot_spend_pause_zoom

# %%
# MCMCLatentStock on S2 — should recover LTC during spend pausedf = load_scenario("data/raw", "S2")obs, truth = split_observed_truth(df)model = MCMCLatentStock()model.fit(obs, {"backend": "map"})decomp = model.decompose(obs)scores = score_model(decomp, truth, model_name="mcmc_stock", scenario="S2")print("MCMC S2 pause recovery:", scores["diagnostics"])
