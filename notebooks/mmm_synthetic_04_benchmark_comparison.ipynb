# %%
import os, sys
from pathlib import Path

# Anchor working directory to repo root regardless of where notebook is launched
repo_root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "pyproject.toml").exists())
os.chdir(repo_root)
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

print(f"Working dir: {repo_root}")

# %% [markdown]
# # 04 — Full Benchmark Comparison
#
# Load all result JSONs and build paper-ready benchmark tables and figures.

# %%
from ltc.evaluation.benchmark import load_results, build_benchmark_table, rank_models, save_benchmarkfrom ltc.visualization.benchmark_plot import plot_recovery_heatmap, plot_scenario_radarimport matplotlib.pyplot as plt

# %%
# Load all resultsresults = load_results("outputs/results")print(f"Loaded {len(results)} result files")

# %%
# Build recovery accuracy heatmap (models x scenarios)benchmark = build_benchmark_table(results, metric="recovery_accuracy")print(benchmark)fig, ax = plt.subplots(figsize=(10,7))plot_recovery_heatmap(benchmark, ax=ax)plt.tight_layout()plt.savefig("outputs/reports/recovery_heatmap.png", dpi=150, bbox_inches="tight")plt.show()

# %%
# Rank models and save summary tableranking = rank_models(benchmark)print(ranking)save_benchmark(benchmark, "outputs/reports/benchmark_recovery_accuracy.csv")
